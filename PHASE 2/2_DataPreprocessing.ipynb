# %% [markdown]
# ### GIAI ĐOẠN 2: TIỀN XỬ LÝ DỮ LIỆU
# ---
# - **Về công cụ**: Sử dụng numpy và pandas để tiền xử lý dữ liệu.
# - Bước này dùng để tiền xử lý dữ liệu, task có sẵn ở bên dưới.
# ---

# %%
# Import thư viện cần thiết để tiền xử lý dữ liệu
import pandas as pd
import numpy as np

# %%
dfPlayer = pd.read_csv("player_data.csv")
dfPlayer
# Out:
#            Player name  Appearances  Goals  Wins  Losses Goals.1  \
# 0     Brenden Aaronson           14      1     4       7       1
# 1          Zach Abbott            0      0     0       0       0
# 2         Terry Ablade            0      0     0       0       0
# 3        Tammy Abraham           89     26    36      33      26
# 4       Adam Armstrong           52      3     8      32       3
# ...                ...          ...    ...   ...     ...     ...
# 1083      Isaiah Brown           15      0     2       7       0
# 1084     Marcus Browne            0      0     0       0       0
# 1085        Alex Bruce           48      0    10      28       4
# 1086       Chris Brunt          269     24    76     119      24
# 1087       Reece Burke            5      0     1       3       2
#
#       Goals per match  Headed goals Goals with right foot  \
# 0                0.07             0                     1
# 1                0.00             0                    0%
# 2                0.00             0                     0
# 3                0.29             3                    20
# 4                0.06             0                     1
# ...               ...           ...                   ...
# 1083             0.00             0                     0
# 1084             0.00             0                     0
# 1085            46.00            56                   70%
# 1086             0.09             3                     0
# 1087             4.00             6                   83%
#
#       Goals with left foot  ...  Interceptions Clearances Headed clearances  \
# 0                        0  ...            1.0        5.0               1.0
# 1                        0  ...            0.0        0.0               0.0
# 2                        0  ...            NaN        NaN               NaN
# 3                        1  ...            NaN        NaN               NaN
# 4                        2  ...            NaN        NaN               NaN
# ...                    ...  ...            ...        ...               ...
# 1083                     0  ...            1.0        2.0               0.0
# 1084                     0  ...            0.0        0.0               0.0
# 1085                     1  ...            0.0       25.0               0.0
# 1086                    21  ...          375.0      445.0             176.0
# 1087                     0  ...            0.0        3.0               0.0
#
#      Recoveries Duels won Duels lost Succesful 50/50s Aerial battles won  \
# 0            68        77        106             19.0                6.0
# 1             0         0          0              0.0                0.0
# 2           NaN       NaN        NaN              NaN                NaN
# 3           NaN       NaN        NaN              NaN                NaN
# 4           NaN       NaN        NaN              NaN                NaN
# ...         ...       ...        ...              ...                ...
# 1083         17        27         44              6.0               15.0
# 1084          0         0          0              0.0                0.0
# 1085          0         0          0              0.0                1.0
# 1086      1,234       907      1,007            105.0              275.0
# 1087          0         0          0              0.0                0.0
#
#      Aerial battles lost Errors leading to goal
# 0                   17.0                    0.0
# 1                    NaN                    NaN
# 2                    NaN                    NaN
# 3                    NaN                    NaN
# 4                    NaN                    NaN
# ...                  ...                    ...
# 1083                24.0                    0.0
# 1084                 0.0                    0.0
# 1085                 NaN                    NaN
# 1086               280.0                    2.0
# 1087                 NaN                    NaN
#
# [1088 rows x 42 columns]

# %% [markdown]
# #### Task 1: Data explorations:
# - Có bao nhiều và cột mà dữ liệu có?
# - Mỗi hàng có ý nghĩa như thế nào với bộ dữ liệu?
# - Giải thích tất cả các thuộc tính có trong bảng, phân loại nó thuộc dạng Numeric hay Category.
# - Chọn ra những thuộc tính cần thiết để xây dựng mô hình và trả lời những câu hỏi có ý nghĩa.

# %% [markdown]
# #### Task 2:
# - Liệt kê các cột bị thiếu (List chứa tên cột có dữ liệu rỗng, thiếu, Nan)
# - Liệt kê các dòng bị thiếu (như trên)
# - Điền các dòng, thiếu đó thành giá trị NaN của Pandas.
# - Có hàng nào bị trùng lắp dữ liệu không?
#   - Trên bộ dữ liệu có một số cầu thủ (sau dòng 980) trở đi là bị trùng lắp về tên nhưng không trùng lắp về thuộc tính. Thực hiện loại bỏ các cầu thủ có cùng tên nhưng xuất hiện ở lần thứ 2 (cầu thủ xuất hiện lần thứ 2 thì bỏ).
# - Yêu cầu: Làm bằng thư viện Pandas.

# %% [markdown]
# #### Task 3: Data Preprocessing
# - Loại bỏ các kí hiệu, các kí tự đặc biệt '/n', '/t', '%',... trong các cột dữ liệu.
# - Chuyển đổi kiểu dữ liệu sao cho phù hợp với bài và để tính toán về sau (kiểu dữ liệu của Pandas).
# - In ra những dòng trống, rỗng, NaN, toàn bộ là 0 và thuộc tính tương ứng của nó để bổ sung sau.
# - Điền giá trị thiếu bằng phương pháp constant (điền giá trị 0), mean, median vào giá trị thiếu cho cột numeric, và mode cho cột categorical, làm tròn ở 2 chữ số thập phân.
