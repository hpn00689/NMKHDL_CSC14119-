# %% [markdown]
# ### GIAI ĐOẠN 1: LẤY DỮ LIỆU TRÊN WEBSITE
# ---
# - **Về công cụ**: Sử dụng Selenimum và BeautifulSoup để lấy dữ liệu tự động từ website.
# - **Điều kiện tiên quyết**: Có cài đặt Chrome drivers và thư viện Selenium.
# ---

# %% [markdown]
# #### **1. Import các thư viện cần thiết cho crawling data:**

# %%
# Thư viện beautifulSoup:
from bs4 import BeautifulSoup

# Thư viện selenium và lấy ra webdriver:
from selenium import webdriver
from selenium.webdriver.common.by import By

# Thư viện time để sử dụng các hàm liên quan đến thời gian
import time

# Thư viện xử lý mảng, dataframe: 
import pandas as pd
import numpy as np

# Thư viện tải web driver up-to-date
import chromedriver_autoinstaller
chromedriver_autoinstaller.install()

# %% [markdown]
# #### **2. Tiến hành các bước lấy dữ liệu:**

# %%
# Mở trình duyệt Chrome ở chế độ toàn màn hình:
browser = webdriver.Chrome()
browser.maximize_window()

# %%
# Mở trang chủ của trang cần lấy dữ liệu, ở đây là website Premierleague.com
browser.get('https://www.premierleague.com/players')

# %% [markdown]
# ---
#
# ##### *Giai đoạn 1: Tìm hiểu website và xử lý lần vào đầu tiên*
# - **Một số lưu ý** khi mới bắt đầu vào website:
#   - Khi mở website trên lên, mới bắt đầu vào ta sẽ thấy một bảng thông báo là phải **Accept all cookies** thì ta mới <br> có thể thực hiện tiếp trên dữ liệu.
#   - Có một điểm bất cập ở đây là khi mới bắt đầu vào trang, ta phải đợi nó tải hết một số dữ liệu nên sẽ bị trễ một khoảng thời gian. <br>Với thời gian thực thi của cell tìm và click vào button accept all cookies, nó luôn luôn báo lỗi nên chúng em phải dùng phương thức <br> **time.sleep(3)** để hoãn lại 3 giây chờ web tải hoàn chỉnh rồi sau đó mới có thể nhấn vào được nút.
#   - 3 giây là thời gian chúng em quan sát được để website tải được hoàn chỉnh ở môi trường lý tưởng (băng thông mạnh,...).
# - Lỗi trả về và cách sửa lỗi được tham khảo: [Stackoverflow](https://stackoverflow.com/questions/65120003/elementnotinteractableexception-using-selenium-in-python)
#
# ---

# %%
# Phương thức delay thời gian tải trang.
time.sleep(5)   

# button_Class: Kiểm tra trên website rồi lấy thủ công về.
button_Class = '//button[@class="_2hTJ5th4dIYlveipSEMYHH BfdVlAo_cgSVjDUegen0F js-accept-all-close"]'

# Tìm chỗ button_class đó rồi thực hiện click vào (Accept all cookies).
browser.find_element(By.XPATH, button_Class).click()

# %% [markdown]
# ----
# - **Kiểu tải dữ liệu của trang:**
#   - Giống như Facebook hay Twitter, trang này sẽ tải gần như vô hạn khi tiếp tục kéo xuống dưới cuối.
#   - Nhóm em thực hiện đoạn code liên tục kéo xuống trang dữ liệu cho đến khi nào nó tải mới, làm hoài như vậy cho đến khi trang đưa ra những dữ liệu cuối cùng.
# - Kéo trang để lấy hết đoạn html đầy đủ chứa các tag href - chứa toàn bộ link các cầu thủ.
# - Đoạn code kéo trang được tham khảo tại: [Python forum](https://python-forum.io/thread-20175.html)
# ----

# %%
# Thời gian đợi cuộn tải đữ liệu
SCROLL_PAUSE_TIME = 20

# Lấy kích thước trang ở cuối.
last_height = browser.execute_script("return document.body.scrollHeight")

while True:
    # Cuộn đến cuối trang.
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Cài đặt thời gian để load trang khi nó mở rộng thêm dữ liệu.
    time.sleep(SCROLL_PAUSE_TIME)

    # Tính toán với chiều dài cuộn mới và so sánh với chiều cao trang ban đầu.
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %% [markdown]
# ---
#
# ##### *Giai đoạn 2: Lấy từng chỉ số cầu thủ và đưa ra kết quả cuối cùng.*
#
# - Sử dụng song song các thư viện Selenium và thư viện BeautifulSoup để thực hiện việc lấy dữ liệu website chứa thông tin từng cầu thủ.
# - Vì là dạng tổ chức theo các trang nên việc lấy dữ liệu sẽ rất lâu (chạy 146 phút mới hoàn thành việc lấy hết dữ liệu).
# ---

# %%
# List chứa danh sách các liên kết đến thông tin cá nhân của một cấu thủ.
href_pos_lst = []

# Lấy toàn bộ source html trên trang. 
html_text = browser.page_source
soup = BeautifulSoup(html_text)

# Đóng trang web: 
browser.close()

# %%
# Lấy các thẻ chứa vị trí của các cầu thủ
player_pos = soup.find_all('td', 'hide-s')
player_pos = player_pos[0::2]

for i in range(len(player_pos)):
    player_pos[i] = player_pos[i].get_text()

player_pos = np.array(player_pos)

# %%
# Lấy các thẻ chứa các đường dẫn của các cầu thủ
player_href = []
player_link = soup.find_all('a', 'playerName')

# Xử lý link để truy cập vào link nhanh
for link in player_link: 
    raw_link = 'https:' + link.get('href')
    true_link = raw_link.replace('overview', 'stats')
    player_href.append(true_link)

player_href = np.array(player_href)

# %%
# Biến 2 mảng thông tin trên thành mảng 2 chiều để dễ xử lý
href_pos_lst = np.column_stack((player_pos, player_href))

# %%
# Làm việc trên danh sách cầu thủ: 
forward_player_data = [] 
mid_player_data = [] 
def_player_data = [] 
keeper_player_data = [] 

# Mở lại trình duyệt và tiến hành vào từng cầu thủ
browser = webdriver.Chrome()
browser.maximize_window()

# Vòng lặp duyệt từng link href để vào đượt trang thống kê chỉ số từng cầu thủ.
for index, link in enumerate(href_pos_lst):
    browser.get(link[1])
    # Lúc mới đầu vào sẽ có nút chấp nhận cookies, xử lý nó.
    # if (index == 0):
    #     time.sleep(4)
    #     button_Class = '//button[@class="_2hTJ5th4dIYlveipSEMYHH BfdVlAo_cgSVjDUegen0F js-accept-all-close"]'
    #     browser.find_element(By.XPATH, button_Class).click()
        
    html_text = browser.page_source
    soup = BeautifulSoup(html_text)
    
    # Tìm ra tất cả các thẻ như tên, các mục thống kê rồi lấy các nội dung từ đó.
    name = soup.find('div', 'name t-colour').get_text()
    if name == 'Ben Chrisene':
        continue
    topStat = soup.find_all('span', 'allStatContainer')
    # Đưa các nội dung vào mảng một chiều như một phần tử của mảng 2 chiều toàn bộ tập dữ liệu.
    one_player = [st.get_text().strip() for st in topStat]
    one_player.insert(0, name)
    print(name, len(one_player))

    if (link[0] == 'Goalkeeper'):
        keeper_player_data.append(one_player)
    elif (link[0] == 'Forward'):    
        forward_player_data.append(one_player)
    elif (link[0] == 'Midfielder'):   
        mid_player_data.append(one_player)     
    elif (link[0] == 'Defender'):   
        def_player_data.append(one_player)
        

browser.close()
# Out:
# Brenden Aaronson 42
# Zach Abbott 40
# Terry Ablade 31
# Tammy Abraham 31
# Adam Armstrong 31
# Adama Traoré 31
# Tyler Adams 42
# Tosin Adarabioyo 40
# Tayo Adaramola 40
# Joshua Addae 40
# Simon Adingra 31
# Adrián 25
# Nayef Aguerd 40
# Rayan Aït-Nouri 40
# Kristoffer Ajer 40
# Manuel Akanji 40
# Nathan Aké 40
# Victor Akinwale 31
# Marc Albrighton 42
# Ryan Alebiosu 40
# Ajibola Alese 40
# Alex Telles 40
# Trent Alexander-Arnold 40
# Alisson 25
# Allan 42
# Charlie Allen 42
# Dele Alli 42
# Miguel Almirón 42
# Marcos Alonso 40
# Julián Álvarez 31
# Álvaro Fernández 25
# William Alves 31
# Steven Alzate 42
# Daniel Amartey 40
# Ethan Ampadu 40
# Joachim Andersen 40
# Joseph Anderson 40
# Florin Andone 31
# André Gomes 42
# Andreas Pereira 42
# Frank Anguissa 42
# Faustino Anjorin 42
# Jaidon Anthony 31
# Michail Antonio 31
# Antony 31
# Paul Appiah 40
# Keenan Appiah-Forson 42
# Billy Arce 42
# Cameron Archer 31
# Alphonse Aréola 25
# Joe Aribo 42
# Stuart Armstrong 42
# Kepa Arrizabalaga 25
# Harry Arter 42
# Arthur 42
# Harrison Ashby 40
# Ryan Astley 40
# Pierre-Emerick Aubameyang 31
# Ludwig Augustinsson 40
# Serge Aurier 40
# Brandon Austin 25
# Zach Awe 40
# Taiwo Awoniyi 31
# Jordan Ayew 31
# Luke Ayling 40
# Miguel Azeez 42
# César Azpilicueta 40
# Abdul Rahman Baba 40
# Baba Fernandes 40
# Finley Back 40
# Loïc Badé 40
# Leon Bailey 31
# Eric Bailly 40
# Stefan Bajcetic 40
# Tiemoué Bakayoko 42
# Lewis Baker 42
# James Balagizi 42
# Ellery Balcombe 25
# Dominic Ballard 31
# Kofi Balmer 42
# Folarin Balogun 31
# Tudor Baluta 40
# Patrick Bamford 31
# Scott Banks 42
# Shandon Baptiste 42
# Ross Barkley 42
# Harvey Barnes 42
# Louie Barry 31
# Ryan Bartley 42
# Lewis Bate 42
# Michy Batshuayi 31
# Nathan Baxter 25
# Gavin Bazunu 25
# Eddie Beach 25
# Mads Bech Sørensen 40
# Owen Beck 40
# Jan Bednarek 40
# Asmir Begovic 25
# Armel Bella-Kotchap 40
# Héctor Bellerín 40
# Ben Woodburn 42
# Filip Benkovic 40
# Rhys Bennett 40
# Saïd Benrahma 31
# Rodrigo Bentancur 42
# Christian Benteke 31
# Lucas Bergström 25
# Steven Bergwijn 31
# Di'Shon Bernard 40
# Bernardo Silva 42
# Ryan Bertrand 40
# Marcus Bettinelli 25
# Owen Bevan 40
# Giulian Biancone 40
# Mads Bidstrup 42
# Mika Biereth 31
# Philip Billing 42
# Nathan Bishop 25
# Yves Bissouma 42
# Harvey Blair 31
# David Boateng 40
# Oscar Bobb 42
# Lamare Bogarde 42
# Mateusz Bogusz 42
# Bendegúz Bolla 40
# Willy Boly 40
# Gaëtan Bong 40
# Sven Botman 40
# Jamie Bowden 42
# Jarrod Bowen 31
# Josh Bowler 42
# Conor Bradley 40
# Robert Brady 42
# Jarrad Branthwaite 40
# Sammy Braybrooke 42
# Nathan Broadhead 31
# Armando Broja 31
# Josh Brooking 40
# David Brooks 42
# Bruno Fernandes 42
# Bruno Guimarães 42
# Bruno Jordão 42
# Lewis Brunt 42
# Joe Bryan 40
# Emiliano Buendía 42
# Hugo Bueno 40
# Dan Burn 40
# Finley Burns 40
# Mason Burstow 31
# Jack Butland 25
# Nathan Butler-Oyedeji 42
# Willy Caballero 25
# Maliq Cadogan 42
# Cafú 42
# Gary Cahill 40
# Moisés Caicedo 42
# Jake Cain 42
# Tom Cairney 42
# Duje Caleta-Car 40
# Dominic Calvert-Lewin 31
# Leonardo Campana 31
# Vontae Campbell 40
# Thomas Cannon 31
# Sergi Canós 31
# Todd Cantwell 42
# Elia Caprile 25
# Cardo Siddik Afraciab 40
# Carlos Vinícius 31
# Scott Carson 25
# Cameron Carter-Vickers 40
# Cesare Casadei 42
# Casemiro 42
# Kaelan Casey 40
# Matty Cash 40
# Timothy Castagne 40
# Edinson Cavani 31
# Cédric Soares 40
# Kallum Cesay 40
# Trevoh Chalobah 40
# Calum Chambers 40
# Kgaogelo Chauke 42
# Daniel Chesters 42
# Ben Chilwell 40
# Chiquinho 31
# Tahith Chong 42
# Hamza Choudhury 42
# Andreas Christensen 40
# Christian Marques 40
# Ryan Christie 42
# Harry Christy 25
# Carney Chukwuemeka 42
# Catalin Cirjan 42
# CJ Egan-Riley 40
# Bobby Clark 42
# Matt Clarke 40
# Leighton Clarkson 42
# Regan Clayton 40
# Nathaniel Clyne 40
# Conor Coady 40
# Jack Colback 42
# Séamus Coleman 40
# Nathan Collins 40
# Levi Colwill 40
# Aaron Connolly 31
# Lewis Cook 42
# Liam Cooper 40
# Theo Corbeanu 31
# Dominic Corness 42
# Maxwel Cornet 31
# Vladimír Coufal 40
# Conor Coventry 42
# Brandon Cover 42
# Matthew Cox 25
# Amario Cozier-Duberry 42
# Michael Craig 42
# Tristan Crama 40
# Billy Crellin 25
# Charlie Cresswell 40
# Cristiano Ronaldo 31
# Marc Cucurella 40
# Luke Cundle 42
# Patrick Cutrone 31
# Luciano D'Auria-Henry 40
# Patson Daka 31
# Dale Taylor 31
# Stuart Dallas 40
# Mikkel Damsgaard 42
# Daniel Podence 42
# Karl Darlow 25
# Josh Dasilva 42
# Tom Davies 42
# Keinan Davis 31
# Craig Dawson 40
# Laurens De Bock 40
# Lucas De Bolle 42
# Kevin De Bruyne 42
# Bobby De Cordova-Reid 31
# David de Gea 25
# James Debayo 40
# Liam Delap 31
# Fabian Delph 42
# Siriki Dembélé 42
# Leander Dendoncker 42
# Will Dennis 25
# Halil Dervisoglu 31
# Destiny Udogie 40
# Alfie Devine 42
# Kiernan Dewsbury-Hall 42
# Amad Diallo 31
# Luis Díaz 31
# Tyler Dibling 42
# Diego Carlos 40
# Diego Costa 31
# Diego Rosa 42
# Eric Dier 40
# Lucas Digne 40
# Diogo Dalot 40
# Diogo Jota 31
# Issa Diop 40
# Elijah Dixon-Bonner 42
# Moussa Djenepo 42
# Ben Doak 31
# Lewis Dobbin 31
# Matt Doherty 40
# Aaron Donnelly 40
# Cheick Oumar Doucouré 42
# Douglas Luiz 42
# Flynn Downes 42
# Tommy Doyle 42
# Cody Drameh 40
# Martin Dúbravka 25
# Shane Duffy 40
# Paul Dummett 40
# Lewis Dunk 40
# Malcolm Ebiowei 42
# Ederson 25
# Odsonne Édouard 31
# Samuel Edozie 31
# Khayon Edwards 31
# Pierre Ekwah 40
# Anwar El Ghazi 31
# Anthony Elanga 31
# Benjamin Elliott 42
# Mohamed Elyounoussi 42
# Noam Emeran 31
# Emerson 40
# Emerson Royal 40
# Julio Enciso 31
# Christian Eriksen 42
# Pervis Estupiñán 40
# Jonny Evans 40
# Oliver Ewing 42
# Eberechi Eze 42
# Lukasz Fabianski 25
# Fabinho 42
# Fábio Carvalho 42
# Fábio Silva 31
# Fábio Vieira 42
# Fabri 25
# Wout Faes 40
# Malachi Fagan-Walcott 40
# Josh Feeney 42
# Evan Ferguson 31
# Álvaro Fernández 40
# Fernandinho 42
# Billy Fewster 42
# Ryan Finnigan 42
# Junior Firpo 40
# William Fish 40
# Ethan Fitzhugh 42
# Marcelo Flores 42
# Shane Flynn 42
# Phil Foden 42
# Wesley Fofana 40
# Taylor Foran 40
# Michael Forbes 40
# Tyrese Fornah 42
# Pablo Fornals 42
# Adam Forshaw 42
# Marcus Forss 31
# Fraser Forster 25
# Marlon Fossey 40
# Tariqe Fosu-Henry 42
# Chris Francis 40
# Tyrese Francois 42
# Ryan Fraser 42
# Melkamu Frauendorf 42
# Fred 42
# Freddie Woodman 25
# Ryan Fredericks 40
# Tyler Fredricson 40
# Remo Freuler 42
# James Furlong 40
# Gabriel Jesus 31
# Gabriel Magalhães 40
# Gabriel Martinelli 42
# Conor Gallagher 42
# Alejandro Garnacho 31
# James Garner 42
# Dwight Gayle 31
# Paulo Gazzaniga 25
# Jean-Philippe Gbamin 42
# Joe Gelhardt 31
# Brooklyn Genesini 40
# Saman Ghoddos 31
# Morgan Gibbs-White 42
# Lewis Gibson 40
# Alexander Gibson-Hammond 42
# Tarik Gidaree 40
# Bryan Gil 31
# Alex Gilbert 31
# Alfie Gilchrist 40
# Ryan Giles 42
# Mark Gillespie 25
# Billy Gilmour 42
# Ryan Glover 42
# Wilfried Gnonto 31
# Ben Godfrey 40
# Martial Godo 31
# Pierluigi Gollini 25
# Claudio Gomes 42
# Joe Gomez 40
# Gonçalo Guedes 31
# Charlie Goode 40
# Owen Goodman 25
# Lewis Gordon 40
# Daniel Gore 42
# Lewis Grabban 31
# Hubert Graczyk 25
# Lee Grant 25
# Demarai Gray 31
# Jack Grealish 42
# Ben Greenwood 40
# Seán Grehan 40
# Harvey Griffiths 42
# Pascal Groß 42
# Vicente Guaita 25
# Marc Guéhi 40
# Idrissa Gueye 42
# Frédéric Guilbert 40
# Ilkay Gündogan 42
# Patrik Gunnarsson 25
# Darko Gyabi 42
# Erling Haaland 31
# Oliver Hammond 42
# Reece Hannam 40
# Isak Hansen-Aaröen 42
# Riley Harbottle 40
# Bjorn Hardley 40
# Luke Harris 42
# Jack Harrison 42
# Taylor Harwood-Bellis 40
# Kortney Hause 40
# Kai Havertz 42
# Kaine Hayden 40
# Maxwell Haygarth 42
# Tom Heaton 25
# Michael Hector 40
# Krisztián Hegyi 25
# Karl Hein 25
# Hélder Costa 31
# Jordan Henderson 42
# Jeff Hendrick 42
# Wayne Hennessey 25
# Rico Henry 40
# Yangel Herrera 42
# Aaron Hickey 40
# James Hill 40
# Jack Hinchy 42
# George Hirst 42
# Leo Hjelde 40
# Joseph Hodge 42
# Ki-Jana Hoever 40
# Rob Holding 40
# Mason Holgate 40
# Ethan Horvath 25
# Conor Hourihane 42
# Callum Hudson-Odoi 42
# Will Hughes 42
# Joe Hugill 31
# Bashir Humphreys 40
# Omari Hutchinson 42
# Hwang Hee-Chan 31
# Hwang Ui-Jo 31
# Pierre-Emile Højbjerg 42
# Bradley Ibrahim 42
# Kelechi Iheanacho 31
# Danny Ings 31
# Nicolas Ioannou 40
# Tim Iroegbunam 42
# Alexander Isak 31
# Ivan Cavaleiro 31
# Daniel Iversen 25
# Alex Iwobi 31
# Eldin Jakupovic 25
# Reece James 40
# Vitaly Janelt 42
# Pontus Jansson 40
# Julian Jeanvier 40
# Jack Jenkins 42
# Teddy Jenks 42
# Mathias Jensen 42
# Jeong Sang-Bin 31
# Raúl Jiménez 31
# João Cancelo 40
# João Moutinho 42
# João Palhinha 42
# João Virgínia 25
# Joelinton 31
# Kyle John 40
# Brennan Johnson 31
# Sam Johnstone 25
# Curtis Jones 42
# Jonny 40
# Jorginho 42
# José Sá 25
# Juan Larios 40
# James Justin 40
# Issa Kaboré 40
# Sasa Kalajdzic 31
# Boubacar Kamara 42
# Harry Kane 31
# N'Golo Kanté 42
# Michal Karbownik 40
# Loris Karius 25
# Hayao Kawabe 42
# Kayky 31
# Moise Kean 31
# Michael Keane 40
# Neeskens Kebano 42
# Joshua Keeley 25
# Thilo Kehrer 40
# Naby Keïta 42
# Caoimhín Kelleher 25
# Lloyd Kelly 40
# Kenedy 42
# Nohan Kenneh 42
# Jonjoe Kenny 40
# Reda Khadra 42
# Kiko Casilla 25
# Gavin Kilkenny 42
# Maximilian Kilman 40
# Alex Kirk 40
# Kristoffer Klaesson 25
# Mateusz Klich 42
# Ben Knight 31
# Anthony Knockaert 42
# Robin Koch 40
# Sead Kolasinac 40
# Ibrahima Konaté 40
# Terence Kongolo 40
# Ezri Konsa 40
# Kalidou Koulibaly 40
# Billy Koumetio 40
# Cheikhou Kouyaté 42
# Mateo Kovacic 42
# Matej Kovár 25
# Kacper Kozlowski 42
# Emil Krafth 40
# Alex Král 42
# Rasmus Kristensen 40
# Dejan Kulusevski 42
# Layvin Kurzawa 40
# Alexandre Lacazette 31
# Ethan Laird 40
# Adam Lallana 42
# Tariq Lamptey 40
# Daniel Langley 25
# Manuel Lanzini 42
# Aymeric Laporte 40
# Richie Laryea 40
# Jamaal Lascelles 40
# Roméo Lavia 42
# Marcel Lavinier 40
# Nico Lawrence 40
# Zan-Luk Leban 25
# Dexter Lembikisa 40
# Clément Lenglet 40
# Bernd Leno 25
# Léo Bonatini 31
# Marc Leonard 42
# Jefferson Lerma 42
# Thakgalo Leshabela 42
# Rico Lewis 40
# Lewis Hall 42
# Keane Lewis-Potter 31
# Myles Lewis-Skelly 42
# Victor Lindelöf 40
# Hayden Lindley 42
# Jesse Lingard 42
# Mateusz Lis 25
# Tino Livramento 40
# Diego Llorente 40
# Hugo Lloris 25
# Giovani Lo Celso 42
# Jürgen Locadia 31
# Ruben Loftus-Cheek 42
# Joe Lolley 31
# Andy Lonergan 25
# Shane Long 31
# Emmanuel Longelo 40
# Sean Longstaff 42
# Ademola Lookman 31
# Jonas Lössl 25
# Jamal Lowe 31
# Luca Ashby-Hammond 25
# Lucas Moura 31
# Lucas Paquetá 42
# Romelu Lukaku 31
# Lyanco 40
# Lyle Taylor 31
# Brooklyn Lyons-Foster 40
# Isaac Mabaya 42
# Alexis Mac Allister 42
# James Maddison 42
# Paris Maghoma 42
# Harry Maguire 40
# Riyad Mahrez 31
# Kobbie Mainoo 42
# Ainsley Maitland-Niles 42
# Malachi Boateng 42
# Tyrell Malacia 40
# Sadio Mané 31
# Orel Mangala 42
# Javier Manquillo 40
# Sékou Mara 31
# Marc Jurado 40
# Marçal 40
# Marcelo Pitaluga 25
# Solly March 42
# Emiliano Marcondes 42
# Pablo Marí 40
# Dilan Markanday 31
# Marquinhos 31
# Filip Marschall 25
# Anthony Martial 31
# David Martin 25
# Emiliano Martínez 25
# Arthur Masuaku 40
# Tawanda Maswanhise 42
# Juan Mata 42
# Mateo Joseph 31
# Jean-Philippe Mateta 31
# Matheus Nunes 42
# Nemanja Matic 42
# Joël Matip 40
# Matthew Craig 42
# Remi Matthews 25
# Matty Longstaff 42
# Neal Maupay 31
# Konstantinos Mavropanos 40
# Alfie Mawson 40
# Kevin Mbabu 40
# Loïc Mbe Soh 40
# Luke Mbete 40
# Bryan Mbeumo 42
# Xavier Mbuyamba 40
# James McArthur 42
# James McAtee 42
# Kasey McAteer 42
# Connor McAvoy 40
# Alfie McCalmont 42
# Liam McCarron 42
# Alex McCarthy 25
# Thomas McGill 25
# John McGinn 42
# Scott McKenna 40
# Stuart McKinstry 42
# Dwight McNeil 31
# Charlie McNeill 31
# Scott McTominay 42
# Ben Mee 40
# Hannibal Mejbri 42
# Édouard Mendy 25
# Teden Mengi 40
# Chris Mepham 40
# Illan Meslier 25
# Matt Miazga 40
# Alex Mighten 31
# Luka Milivojevic 42
# Amari Miller 42
# Stanley Mills 42
# James Milner 42
# Yerry Mina 40
# Takumi Minamino 42
# Tyrone Mings 40
# Tyrick Mitchell 40
# Kaoru Mitoma 31
# Aleksandar Mitrovic 31
# Jakub Moder 42
# Mohamed Elneny 42
# Mohamed Salah 31
# Zane Monlouis 40
# Jacob Montes 42
# Fionn Mooney 42
# Kieffer Moore 31
# Andrew Moran 42
# Pablo Moreno 31
# Jimmy Morgan 31
# Nathan Moriah-Welsh 42
# Tyler Morton 42
# Yerson Mosquera 40
# Malik Mothersille 31
# Louie Moulden 25
# Mason Mount 42
# Fabian Mrozek 25
# Divin Mubama 31
# Romaine Mundle 42
# Arijanet Muric 25
# Jacob Murphy 42
# Sam Murray 40
# Mateusz Musialowski 31
# Yoshinori Muto 31
# Enock Mwepu 42
# Vitaliy Mykolenko 40
# Daniel N'Lundulu 31
# Marvelous Nakamba 42
# Adler Nascimento 31
# Wilfred Ndidi 42
# Tanguy Ndombélé 42
# Reiss Nelson 31
# Nélson Semedo 40
# Neto 25
# Moussa Niakhaté 40
# Saúl Ñíguez 42
# Eddie Nketiah 31
# Niels Nkounkou 40
# Mark Noble 42
# James Norris 40
# Darwin Núñez 31
# Nuno da Costa 42
# Nuno Tavares 40
# Ethan Nwaneri 42
# Christian Nørgaard 42
# Jake O'Brien 40
# Oliver O'Neill 42
# Tommi O'Reilly 42
# Michael Obafemi 31
# Ademipo Odubeko 31
# Chituru Odunze 25
# Odeluga Offiah 40
# Angelo Ogbonna 40
# Mazeed Ogungbo 40
# Braian Ojeda 42
# Sheyi Ojo 31
# Armstrong Oko-Flex 31
# Ferdinand Okoh 42
# Arthur Okonkwo 25
# Ademola Ola-Adebomi 31
# Kazeem Olaigbe 31
# Michael Olise 42
# Robin Olsen 25
# David Omilabu 31
# Tobi Omole 40
# Amadou Onana 42
# Josh Onomah 42
# Tyler Onyango 42
# Frank Onyeka 42
# Lewis Orford 42
# Divock Origi 31
# Stefan Ortega 25
# Owen Otasowie 42
# Salah-Eddine Oulad M'hand 42
# Alex Oxlade-Chamberlain 42
# Maximillian Oyedele 42
# Daniel Oyegoke 40
# David Ozoh 42
# Sam Packham 40
# Adrion Pajaziti 42
# Cole Palmer 42
# Jonathan Panzo 40
# Stefan Parkes 40
# Troy Parrott 31
# Thomas Partey 42
# Maksim Paskotsi 40
# Charlie Patino 42
# Nathan Patterson 40
# Lewis Payne 42
# Ben Pearson 42
# Myles Peart-Harris 42
# Pedro Neto 31
# Facundo Pellistri 42
# Nicolas Pépé 31
# Ayoze Pérez 31
# Ivan Perisic 42
# Sonny Perkins 31
# Romain Perraud 40
# Cameron Peupion 42
# Philippe Coutinho 42
# Nathaniel Phillips 40
# Jaden Philogene 42
# Jordan Pickford 25
# Ethan Pinnock 40
# Cameron Plain 25
# Luke Plange 31
# Paul Pogba 42
# Nick Pope 25
# Freddie Potts 42
# Ian Poveda-Ocampo 31
# Dennis Praet 42
# Aaron Pressley 31
# Isaac Price 42
# Christian Pulisic 42
# Jarell Quansah 40
# Daniel Quick 40
# Sebastian Quirk 42
# Luka Racic 40
# Jesurun Rak-Sakyi 42
# Calvin Ramsay 40
# Aaron Ramsdale 25
# Jacob Ramsey 42
# Darren Randolph 25
# Dion Rankine 42
# Raphinha 31
# Marcus Rashford 31
# David Raya 25
# Jadan Raymond 42
# Tim Ream 40
# Nathan Redmond 42
# Harrison Reed 42
# Sergio Reguilón 40
# Renan Lodi 40
# Ricardo Pereira 40
# Declan Rice 42
# Taylor Richards 42
# Richarlison 31
# Jairo Riedewald 42
# Matt Ritchie 42
# Roberto Firmino 31
# Haydon Roberts 40
# Andrew Robertson 40
# Antonee Robinson 40
# Joel Robles 25
# Marc Roca 42
# Marek Rodák 25
# Kaden Rodney 42
# Joe Rodon 40
# Rodri 42
# Rodrigo 31
# Rodrigo Muniz 31
# James Rodríguez 42
# Mads Roerslev 40
# Morgan Rogers 31
# Cristian Romero 40
# Oriol Romeu 42
# Connor Ronan 42
# Salomón Rondón 31
# Zeno Rossi 40
# Joe Rothwell 42
# Rúben Dias 40
# Rúben Neves 42
# Rúben Vinagre 40
# John Ruddy 25
# Antonio Rüdiger 40
# Rúnar Rúnarsson 25
# Carl Rushworth 25
# Dominic Sadi 31
# Charles Sagoe Junior 31
# Allan Saint-Maximin 31
# Romain Saïss 40
# Bukayo Saka 31
# William Saliba 40
# Mohammed Salisu 40
# Brice Samba 25
# Albert Sambi Lokonga 42
# Ishé Samuels-Smith 40
# Robert Sánchez 25
# Jadon Sancho 31
# Dion Sanderson 40
# Philippe Sandler 40
# Morgan Sanson 42
# Matija Sarkic 25
# Jeremy Sarmiento 31
# Malang Sarr 40
# Charlie Savage 42
# Christian Saydee 31
# Charlie Sayers 40
# Gianluca Scamacca 31
# Oliver Scarles 42
# Dane Scarlett 31
# Fabian Schär 40
# Kjell Scherpen 25
# Jeffrey Schlupp 42
# Kasper Schmeichel 25
# Kristian Sekularac 42
# Marcos Senesi 40
# Jean Michaël Seri 42
# Steven Sessegnon 40
# Jamie Shackleton 42
# Xherdan Shaqiri 42
# Teddy Sharman-Lowe 25
# Luke Shaw 40
# Jonjo Shelvey 42
# Joe Sheridan 40
# Shola Shoretire 31
# Abdallah Sima 31
# Dynel Simeu 40
# Ellis Simms 31
# Kamarai Simon-Swyer 31
# Xavier Simons 42
# Viljami Sinisalo 25
# Luis Sinisterra 31
# Moussa Sissoko 42
# Oliver Skipp 42
# Cieran Slicker 25
# Gabriel Slonina 25
# Thierry Small 40
# William Smallbone 42
# Matt Smith 42
# Emile Smith Rowe 42
# Alex Smithies 25
# Joe Snowdon 42
# Dominic Solanke 31
# Manor Solomon 31
# Son Heung-Min 31
# Andreas Söndergaard 25
# Jude Soonsup-Bell 31
# Tomás Soucek 42
# Boubakary Soumaré 42
# Lino Sousa 40
# Kamal Sowah 42
# Çaglar Söyüncü 40
# Djed Spence 40
# Jack Spong 42
# Jack Stacey 40
# Junior Stanislas 42
# Jay Stansfield 31
# Jason Steele 25
# Jed Steer 25
# Zack Steffen 25
# Jack Stephens 40
# Raheem Sterling 31
# Finley Stevens 40
# Layton Stewart 31
# Jakub Stolarczyk 25
# John Stones 40
# James Storer 25
# Thomas Strakosha 25
# Robert Street 31
# Pascal Struijk 40
# Thanawat Suengchitthawon 42
# Crysencio Summerville 42
# Sam Surridge 31
# Will Swan 31
# Zak Swanson 40
# Sil Swinkels 40
# Japhet Tanganga 40
# Matt Targett 40
# James Tarkowski 40
# Percy Tau 31
# Marcus Tavernier 42
# Slobodan Tedic 31
# Nathan Tella 42
# Kenny Tete 40
# Thiago 42
# Thiago Silva 40
# Luke Thomas 40
# Dominic Thompson 40
# Youri Tielemans 42
# Kieran Tierney 40
# Tobias Figueiredo 40
# Harry Toffolo 40
# Lorent Tolaj 31
# Takehiro Tomiyasu 40
# James Tomkins 40
# Ivan Toney 31
# Lucas Torreira 42
# Ferran Torres 31
# Cenk Tosun 31
# Toti 40
# Andros Townsend 42
# Bertrand Traoré 31
# Mark Travers 25
# Ryan Trevitt 42
# Trézéguet 42
# Trincão 31
# Kieran Trippier 40
# Leandro Trossard 31
# Nathan Trott 25
# Auston Trusty 40
# Konstantinos Tsimikas 40
# Antef Tsoungui 40
# Axel Tuanzebe 40
# Matt Turner 25
# Ed Turns 40
# Harry Tyrer 25
# Deniz Undav 31
# Harvey Vale 42
# Joel Valencia 31
# Yan Valery 40
# Donny van de Beek 42
# Sepp van den Berg 40
# Virgil van Dijk 40
# Jan Paul van Hecke 40
# Raphaël Varane 40
# Jamie Vardy 31
# Joël Veltman 40
# Jannik Vestergaard 40
# Matthew Vigor 42
# Radek Vítek 25
# Nikola Vlasic 42
# Jake Vokins 40
# Jack Wadham 42
# Theo Walcott 31
# Kyle Walker 40
# Kyle Walker-Peters 40
# Reuell Walters 40
# Christian Walton 25
# Aaron Wan-Bissaka 40
# Wanya Marçal-Madivadua 42
# Joel Ward 40
# James Ward-Prowse 42
# Lewis Warrington 42
# Ollie Watkins 31
# Noah Watson 40
# Kelland Watts 40
# Adam Webster 40
# Jensen Weir 42
# Danny Welbeck 31
# Reece Welch 40
# Charlie Wellens 40
# Jack Wells-Morrison 42
# Timo Werner 31
# Wesley 31
# Charlie Whitaker 42
# Ben White 40
# Alfie Whiteman 25
# Joe Whitworth 25
# Dylan Williams 40
# Willian 31
# Joe Willock 42
# Keehan Willows 25
# Harry Wilson 42
# Thomas Wilson-Brown 42
# Josh Wilson-Esbrand 40
# Harry Winks 42
# Yoane Wissa 42
# Max Woltman 31
# Chris Wood 31
# Joe Wormleighton 42
# Joe Worrall 40
# Callum Wright 42
# Xande Silva 31
# Granit Xhaka 42
# Andrii Yarmolenko 31
# Yegor Yarmolyuk 42
# Ryan Yates 42
# Ashley Young 40
# Nathan Young-Coombes 31
# Wilfried Zaha 31
# Denis Zakaria 42
# Jan Zamburek 42
# Zanka 40
# Jordan Zemura 40
# Andi Zeqiri 31
# Zidane Iqbal 42
# Oleksandr Zinchenko 42
# Hakim Ziyech 42
# Kurt Zouma 40
# Oliwier Zych 25
# Martin Ødegaard 42
# Leo Østigård 40

# %%
dfForward = pd.DataFrame(forward_player_data)
dfForward.columns = ['Player name', 'Appearances', 'Goals Overview', 'Wins', 'Losses', 'Goals', 'Goals per match',
                    'Headed goals', 'Goals with right foot', 'Goals with left foot',
                    'Penalties scored', 'Freekicks scored', 'Shots',
                    'Shots on target', 'Shooting accuracy', 'Hit woodwork',
                    'Big chances missed', 'Assists', 'Passes', 'Passes per match',
                    'Big Chances Created', 'Crosses', 'Yellow cards', 'Red cards',
                    'Fouls', 'Offsides', 'Tackles', 'Blocked shots',
                    'Interceptions', 'Clearances', 'Headed Clearance']

# %%
dfForward.to_csv('forward.csv', index=False)

# %%
dfMid = pd.DataFrame(mid_player_data)
dfMid.columns = ['Player name', 'Appearances', 'Goals Overview', 'Wins', 'Losses', 'Goals', 'Goals per match',
                    'Headed goals', 'Goals with right foot', 'Goals with left foot',
                    'Penalties scored', 'Freekicks scored', 'Shots', 'Shots on target', 
                    'Shooting accuracy %', 'Hit woodwork', 'Big chances missed', 'Assists',
                    'Passes', 'Passes per match', 'Big chances created', 'Crosses', 'Cross accuracy %',
                    'Through balls', 'Accurate long balls', 'Yellow cards', 'Red cards',
                    'Fouls', 'Offsides', 'Tackles', 'Tackle success %', 'Blocked shots',
                    'Interceptions', 'Clearances', 'Headed clearances', 'Recoveries', 'Duels won',
                    'Duels lost', 'Succesful 50/50s', 'Aerial battles won', 'Aerial battles lost', 
                    'Errors leading to goal']

# %%
dfMid.to_csv('midfielder_data.csv', index=False)

# %%
dfDef = pd.DataFrame(def_player_data)
dfDef.columns = ['Player name', 'Appearances', 'Goals Overview', 'Wins', 'Losses', 'Clean sheets', 
                'Goals Conceded', 'Tackles', 'Tackle success' , 'Last man tackles',
                'Blocked shots', 'Interceptions', 'Clearances', 'Headed Clearance',
                'Clearances off line', 'Recoveries', 'Duels won', 'Duels lost', 'Successful 50/50s',
                'Aerial battles won', 'Aerial battles lost', 'Own goals', 'Errors leading to goal',
                'Assists', 'Passes', 'Passes per match', 'Big Chances Created', 'Crosses',
                'Cross accuracy' , 'Through balls', 'Accurate long balls', 'Yellow cards',
                'Red cards', 'Fouls', 'Offsides', 'Goals', 'Headed goals', 'Goals with right foot',
                'Goals with left foot', 'Hit woodwork']

# %%
dfDef.to_csv('defender_data.csv', index=False)

# %%
dfKeeper = pd.DataFrame(keeper_player_data)
dfKeeper.columns = ['Player name', 'Appearances', 'Goals', 'Wins', 'Losses', 'Saves',
            'Penalties Saved', 'Punches', 'High Claims','Catches',
            'Sweeper clearances', 'Throw outs', 'Goal Kicks',
            'Clean sheets', 'Goals Conceded', 'Errors leading to goal',
            'Own goals', 'Yellow cards', 'Red cards', 'Fouls', 'Goals',
            'Assists', 'Passes', 'Passes per match', 'Accurate long balls']

# %%
dfKeeper.to_csv('keeper_data.csv', index=False)

# %% [markdown]
# #### **3. Tiến hành đưa dữ liệu về file csv chung:**
# - Sử dụng thư viện Pandas để đưa mảng chứa các dữ liệu cầu thủ về loại DataFrames của Pandas.
# - Sau khi chuyển về xong, ta viết các thông tin của Dataframe đó về một file CSV và đánh các tên chỉ số cho các cột dựa trên các thuộc tính lấy được.
# - Viết lại vào một file csv để tiện dùng cho sau này.

# %% [markdown]
# ---
# #### 4. Đánh giá và báo cáo giai đoạn crawling data:
# - Đánh giá bước lấy dữ liệu:
#   - **Hạn chế**:
#     - Việc thực thi các cell lấy dữ liệu mất nhiều thời gian (146 phút) để có thể lấy được toàn bộ dữ liệu. Nguyên nhân một phần là vì các thao tác như sang trang cầu thủ, bấm vào nút thống kê để xem chi tiết, lấy các dữ liệu cần thiết... Và cũng một phần là phải thực hiện kéo trang đến cuối để có thể hiện được hết thông tin.
#     - Thay đổi trang web vì phải tìm được trang ít lỗi và tĩnh nhất có thể.
#     - Có một vài trang dữ liệu có định dạng khác format thông thường vì các cầu thủ đó chưa đá nên chưa có dữ liệu, bắt buộc ở bước tiền xử lý dữ liệu thực hiện sau.
#     - Giai đoạn hoàn chỉnh mất nhiều tuần.
#   - **Thuận lợi:**
#     - Không.
